# %%
# !nvidia-smi
# Out:
# Mon Jan 26 16:44:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             46W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Install libraries

# %%
# %pwd
# Out:
# '/content'

# %%
# !pip install -r colab_requirements.txt
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: matplotlib>=3.9.2 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 3)) (3.10.8)
# Requirement already satisfied: numpy>=1.26.4 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 4)) (2.2.6)
# Requirement already satisfied: opencv-python-headless>=4.10.0.84 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 5)) (4.12.0.88)
# Requirement already satisfied: pandas>=2.2.2 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 6)) (2.3.3)
# Requirement already satisfied: Pillow>=10.4.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 7)) (12.0.0)
# Requirement already satisfied: scikit-image>=0.24.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 8)) (0.25.2)
# Requirement already satisfied: scikit-learn>=1.5.2 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: scipy>=1.14.1 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 10)) (1.16.3)
# Requirement already satisfied: tabulate>=0.9.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: torch>=2.4.1 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 12)) (2.9.1)
# Requirement already satisfied: torchvision>=0.19.1 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 13)) (0.24.1)
# Requirement already satisfied: tqdm>=4.66.5 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 14)) (4.67.1)
# Requirement already satisfied: ptflops==0.7 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 15)) (0.7)
# Requirement already satisfied: tensorboard>=2.17.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 16)) (2.20.0)
# Requirement already satisfied: pyyaml in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 17)) (6.0.3)
# Requirement already satisfied: albumentations>=1.4.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from -r colab_requirements.txt (line 18)) (2.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r colab_requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r colab_requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r colab_requirements.txt (line 3)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r colab_requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r colab_requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pyparsing>=3 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r colab_requirements.txt (line 3)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r colab_requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from pandas>=2.2.2->-r colab_requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from pandas>=2.2.2->-r colab_requirements.txt (line 6)) (2025.3)
# Requirement already satisfied: networkx>=3.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from scikit-image>=0.24.0->-r colab_requirements.txt (line 8)) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from scikit-image>=0.24.0->-r colab_requirements.txt (line 8)) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from scikit-image>=0.24.0->-r colab_requirements.txt (line 8)) (2025.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from scikit-image>=0.24.0->-r colab_requirements.txt (line 8)) (0.4)
# Requirement already satisfied: joblib>=1.3.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from scikit-learn>=1.5.2->-r colab_requirements.txt (line 9)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from scikit-learn>=1.5.2->-r colab_requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: filelock in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from torch>=2.4.1->-r colab_requirements.txt (line 12)) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from torch>=2.4.1->-r colab_requirements.txt (line 12)) (4.15.0)
# Requirement already satisfied: setuptools in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from torch>=2.4.1->-r colab_requirements.txt (line 12)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from torch>=2.4.1->-r colab_requirements.txt (line 12)) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from torch>=2.4.1->-r colab_requirements.txt (line 12)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from torch>=2.4.1->-r colab_requirements.txt (line 12)) (2025.12.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from tensorboard>=2.17.0->-r colab_requirements.txt (line 16)) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from tensorboard>=2.17.0->-r colab_requirements.txt (line 16)) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from tensorboard>=2.17.0->-r colab_requirements.txt (line 16)) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from tensorboard>=2.17.0->-r colab_requirements.txt (line 16)) (6.33.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from tensorboard>=2.17.0->-r colab_requirements.txt (line 16)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from tensorboard>=2.17.0->-r colab_requirements.txt (line 16)) (3.1.4)
# Requirement already satisfied: pydantic>=2.9.2 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from albumentations>=1.4.0->-r colab_requirements.txt (line 18)) (2.12.5)
# Requirement already satisfied: albucore==0.0.24 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from albumentations>=1.4.0->-r colab_requirements.txt (line 18)) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from albucore==0.0.24->albumentations>=1.4.0->-r colab_requirements.txt (line 18)) (4.5.1)
# Requirement already satisfied: simsimd>=5.9.2 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from albucore==0.0.24->albumentations>=1.4.0->-r colab_requirements.txt (line 18)) (6.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from pydantic>=2.9.2->albumentations>=1.4.0->-r colab_requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from pydantic>=2.9.2->albumentations>=1.4.0->-r colab_requirements.txt (line 18)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from pydantic>=2.9.2->albumentations>=1.4.0->-r colab_requirements.txt (line 18)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.9.2->-r colab_requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=2.4.1->-r colab_requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/anushk/Desktop/UAD_EDC_DIFF/edc_diff_env/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard>=2.17.0->-r colab_requirements.txt (line 16)) (3.0.3)
#
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %%
import importlib
import configs.config_lungct
importlib.reload(configs.config_lungct)
# Out:
# <module 'configs.config_lungct' from '/Users/anushk/Desktop/UAD_EDC_DIFF/EDC-master/configs/config_lungct.py'>

# %%
import cv2
import matplotlib.pyplot as plt
import os
import pandas as pd

from configs.config_lungct import print_config, BASE_DIR, CODE_DIR, DATASET_DIR
print_config()
# Out:
# ===== LUNG_CT CONFIGURATION =====
# Environment:     local
# Device:          mps
# Base directory:  /Users/anushk/Desktop/UAD_EDC_DIFF/EDC-master
# Code directory:  /Users/anushk/Desktop/UAD_EDC_DIFF/EDC-master/EDC-master
# Dataset root:    /Users/anushk/Desktop/UAD_EDC_DIFF/EDC-master/LUNG_CT
# Train folder:    /Users/anushk/Desktop/UAD_EDC_DIFF/EDC-master/LUNG_CT/train
# Test folder:     /Users/anushk/Desktop/UAD_EDC_DIFF/EDC-master/LUNG_CT/test
# Saved models:    /Users/anushk/Desktop/UAD_EDC_DIFF/EDC-master/EDC-master/saved_models
# ================================

# %% [markdown]
# # Preprocessing

# %%
## PREPARE LUNG CT DATASET - Do not run if preprocessed data is already mounted from Gdrive
## Ensure that the original data is placed in ../LungCT/original/test /train /valid folders
# !python3 ./prepare_dataset/prepare_lungct.py --data-folder ../LungCT/original --save-folder ../LungCT
# Out:
# ===== Lung CT Dataset Preparation Summary =====
# Train NORMAL:   148
# Test NORMAL:    67
# Test ABNORMAL:  597
# =============================================

# %% [markdown]
# # Dataset Description and Sample Input Images

# %%
import os

base_dir = "../LUNGCT" 

for root, dirs, _ in os.walk(base_dir):
    level = root.replace(base_dir, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}|-- {os.path.basename(root)}/")
# Out:
# |-- LUNGCT/
#     |-- test/
#         |-- ABNORMAL/
#         |-- NORMAL/
#     |-- train/
#         |-- NORMAL/

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
from IPython.display import display


base_path = "../LUNGCT"   
sample_count = 2                        

def get_image_counts(base_dir):
    counts = []
    for split in ["train", "test"]:
        split_path = os.path.join(base_dir, split)
        print(split_path)
        if not os.path.exists(split_path):
            print(f"{split_path} does not exist.")
            continue
        for subfolder in sorted(os.listdir(split_path)):
            sub_path = os.path.join(split_path, subfolder)
            if os.path.isdir(sub_path):
                num_images = len([
                    f for f in os.listdir(sub_path)
                    if f.lower().endswith(('.png', '.jpg', '.jpeg'))
                ])
                counts.append({"Set": split, "Class": subfolder, "Count": num_images})
    return pd.DataFrame(counts)

def show_random_samples(base_dir, n=2):
    for split in ["train", "test"]:
        split_path = os.path.join(base_dir, split)
        if not os.path.exists(split_path):
            continue
        
        print(f"\n {split.upper()} SAMPLES\n" + "="*40)
        for subfolder in sorted(os.listdir(split_path)):
            sub_path = os.path.join(split_path, subfolder)
            if os.path.isdir(sub_path):
                images = [
                    os.path.join(sub_path, f)
                    for f in os.listdir(sub_path)
                    if f.lower().endswith(('.png', '.jpg', '.jpeg'))
                ]
                if len(images) == 0:
                    continue
                samples = random.sample(images, min(n, len(images)))

                # Show the images
                fig, axes = plt.subplots(1, len(samples), figsize=(6, 3))
                if len(samples) == 1:
                    axes = [axes]
                for ax, img_path in zip(axes, samples):
                    img = Image.open(img_path)
                    ax.imshow(img)
                    ax.axis("off")
                    ax.set_title(f"{split}/{subfolder}", fontsize=10)
                plt.tight_layout()
                plt.show()

# Show counts
df_counts = get_image_counts(base_path)
display(df_counts)

# Show samples
show_random_samples(base_path, sample_count)
# Out:
# ../LUNGCT/train
# ../LUNGCT/test
#      Set     Class  Count
# 0  train    NORMAL    148
# 1   test  ABNORMAL    529
# 2   test    NORMAL     60
#  TRAIN SAMPLES
# ========================================
#  TEST SAMPLES
# ========================================

# %% [markdown]
# # Training and Testing

# %%
## BASELINE EDC WITH LATENT DIFFUSION MODEL
# !python edc_diff_lungct.py --data_dir ../LungCT --gpu 0
# Out:
# [2026-02-04 06:03:39,753 WARNING] USE GPU: 0 for training
# TrainSet Image Number: 148
# EvalSet Image Number: 589
# === Train Split ===
# Total: 148
# Normal:   148
# Abnormal: 0
#
# === Eval/Test Split ===
# Total: 589
# Normal:   60
# Abnormal: 529
# [2026-02-04 06:03:40,280 INFO] Number of Trainable Params: 50079528
# [2026-02-04 06:03:40,281 INFO] Using Apple Silicon GPU (MPS backend)
# [2026-02-04 06:03:40,595 INFO] model_arch: R50_R50(
#   (edc_encoder): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=2048, out_features=1000, bias=True)
#   )
#   (edc_decoder): ResNetDecoder(
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (shortcut): Sequential(
#           (0): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Upsample(scale_factor=2.0, mode='bilinear')
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (shortcut): Sequential(
#           (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Upsample(scale_factor=2.0, mode='bilinear')
#           (2): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (shortcut): Sequential(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Upsample(scale_factor=2.0, mode='bilinear')
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
# )
# [2026-02-04 06:03:40,598 INFO] Arguments: Namespace(save_dir='./saved_models', save_name='edc_diff_lungct', resume=False, load_path=None, overwrite=True, use_tensorboard=True, epoch=1, num_train_iter=1000, num_eval_iter=250, batch_size=32, eval_batch_size=64, ema_m=0.0, lambda_diff=0.1, lambda_fuse=0.5, optim='AdamW', lr=0.0005, lr_encoder=1e-05, momentum=0.9, weight_decay=0.0001, amp=False, clip=1, data_dir='../LungCT', dataset='lung_ct', train_sampler='RandomSampler', img_size=256, num_workers=4, seed=0, gpu=0, c='', device=device(type='mps'))
# [2026-02-04 06:03:40,598 INFO] [!] data loader keys: dict_keys(['train', 'eval'])
#   0%|                                        | 1/1000 [00:10<3:00:28, 10.84s/it]^C
# Exception ignored on threading shutdown:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 1518, in _shutdown
#     def _shutdown():
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=11, pipe_handle=42)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/spawn.py", line 135, in _main
#     return self._bootstrap(parent_sentinel)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 330, in _bootstrap
#     util.info('process exiting with exitcode %d' % exitcode)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/util.py", line 53, in info
#     def info(msg, *args):
#
# KeyboardInterrupt
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=11, pipe_handle=49)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/spawn.py", line 135, in _main
#     return self._bootstrap(parent_sentinel)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 330, in _bootstrap
#     util.info('process exiting with exitcode %d' % exitcode)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/util.py", line 53, in info
#     def info(msg, *args):
#
# KeyboardInterrupt
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=11, pipe_handle=28)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/spawn.py", line 135, in _main
#     return self._bootstrap(parent_sentinel)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 329, in _bootstrap
#     threading._shutdown()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 1536, in _shutdown
#     atexit_call()
#     ~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 1507, in <lambda>
#     _threading_atexits.append(lambda: func(*arg, **kwargs))
#                                       ~~~~^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/thread.py", line 27, in _python_exit
#     items = list(_threads_queues.items())
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/weakref.py", line 462, in items
#     with _IterationGuard(self):
#          ~~~~~~~~~~~~~~~^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/_weakrefset.py", line 17, in __init__
#     def __init__(self, weakcontainer):
#
# KeyboardInterrupt

# %%
## VISULALIZATION FOR BASELINE EDC
import pickle
import pandas as pd
import os

save_dir = "./saved_models"
save_name = "edc_diff_lungct"
# Load log
save_path = os.path.join(save_dir, save_name, "train_log.pkl")
with open(save_path, "rb") as f:
    logs = pickle.load(f)

# Convert to DataFrame
df = pd.DataFrame(logs)

# List all available metric names
print("=== Available Metrics in Log File ===")
print(df.columns.tolist())

# Show first few rows to see values
print("\n=== Sample Rows ===")
print(df.head())
# Out:
# === Available Metrics in Log File ===
# ['train/total_loss', 'train/e1_std', 'train/e2_std', 'train/e3_std', 'lr', 'train/prefecth_time', 'train/run_time', 'eval/loss', 'eval/f1', 'eval/recall', 'eval/specificity', 'eval/acc', 'eval/AUC', 'eval/AUC1', 'eval/AUC2', 'eval/AUC3', 'it']
#
# === Sample Rows ===
#    train/total_loss  train/e1_std  train/e2_std  train/e3_std       lr  \
# 0          0.498330      0.035483      0.033781      0.026437  0.00001
# 1          0.380766      0.035201      0.033699      0.026319  0.00001
# 2          0.331602      0.035386      0.033723      0.026278  0.00001
# 3          0.302565      0.034927      0.033698      0.026281  0.00001
#
#    train/prefecth_time  train/run_time  eval/loss   eval/f1  eval/recall  \
# 0             0.006089        2.314739   0.624865  0.909832     0.961766
# 1             0.004945        2.720262   0.475149  0.914182     0.949381
# 2             0.005682        2.730462   0.415374  0.928378     0.921379
# 3             0.004246        2.671891   0.388518  0.928552     0.920302
#
#    eval/specificity  eval/acc  eval/AUC  eval/AUC1  eval/AUC2  eval/AUC3   it
# 0          0.648447  0.867017  0.914562   0.881812   0.898787   0.902332  249
# 1          0.705590  0.875657  0.937084   0.894651   0.900119   0.937238  499
# 2          0.853416  0.900826  0.952133   0.911379   0.911221   0.953349  749
# 3          0.857143  0.901202  0.955341   0.910714   0.897044   0.954112  999

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import os

# ====== Load Logs ======
save_dir = "./saved_models"
save_name = "edc_diff_lungct"
save_path = os.path.join(save_dir, save_name, "train_log.pkl")

with open(save_path, "rb") as f:
    logs = pickle.load(f)

df = pd.DataFrame(logs)

# ====== Helper Plot Function ======
def plot_metric(x, y_list, labels, title, ylabel):
    plt.figure(figsize=(8,5))
    for y, label in zip(y_list, labels):
        plt.plot(df[x], df[y], label=label)
    plt.xlabel("Iteration")
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.show()

# ====== 1. Training vs Eval Loss ======
plot_metric("it", ["train/total_loss", "eval/loss"],
            ["Train Loss", "Eval Loss"], "Training vs Eval Loss", "Loss")

# ====== 2. Training vs Eval Accuracy ======
plot_metric("it", ["eval/acc"], ["Eval Accuracy"], "Evaluation Accuracy", "Accuracy")
# (if you had train accuracy logged, add it here as well)

# ====== 3. Evaluation AUC ======
plot_metric("it", ["eval/AUC"], ["AUC"], "Evaluation AUC", "AUC")

# ====== 4. AUC1, AUC2, AUC3 ======
plot_metric("it", ["eval/AUC1", "eval/AUC2", "eval/AUC3"],
            ["AUC1", "AUC2", "AUC3"], "Additional AUC Metrics", "AUC")

# ====== 5. Precision, Recall, Specificity as Bar Chart (last iteration) ======
last_row = df.iloc[-1]
metrics = {
    "F1": last_row["eval/f1"],
    "Recall": last_row["eval/recall"],
    "Specificity": last_row["eval/specificity"],
    "Accuracy": last_row["eval/acc"]
}

plt.figure(figsize=(6,5))
plt.bar(metrics.keys(), metrics.values(), color=["skyblue","lightgreen","salmon","orange"])
plt.title(f"Final Evaluation Metrics (Iteration {int(last_row['it'])})")
plt.ylabel("Score")
plt.ylim(0,1)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.show()

# ====== 6. Summary Table ======
summary = df[["it", "train/total_loss", "eval/loss", "eval/f1", "eval/recall",
              "eval/specificity", "eval/acc", "eval/AUC"]].tail(10)  # last 10 iters
print("=== Iterations Summary ===")
print(summary.to_string(index=False))
# Out:
# === Iterations Summary ===
#  it  train/total_loss  eval/loss  eval/f1  eval/recall  eval/specificity  eval/acc  eval/AUC
# 249          0.498330   0.624865 0.909832     0.961766          0.648447  0.867017  0.914562
# 499          0.380766   0.475149 0.914182     0.949381          0.705590  0.875657  0.937084
# 749          0.331602   0.415374 0.928378     0.921379          0.853416  0.900826  0.952133
# 999          0.302565   0.388518 0.928552     0.920302          0.857143  0.901202  0.955341

# %%
# CHECK DATALEAKAGE
import os
from configs.config_lungct import TRAIN_DIR, TEST_DIR
train_dir = TRAIN_DIR
test_dir = TEST_DIR

train_files = set(os.listdir(train_dir))
test_files = set(os.listdir(test_dir))

# Common filenames
common_files = train_files.intersection(test_files)

print(f"🔍 Total train images: {len(train_files)}")
print(f"🔍 Total test images:  {len(test_files)}")
print(f"⚠️  Common filenames:  {len(common_files)}")

if common_files:
    print("🧩 Possible data leakage — these files exist in both sets:")
    for f in list(common_files)[:10]:  # show first 10
        print("  ", f)
else:
    print("✅ No filename overlap detected.")
# Out:
# 🔍 Total train images: 1000
# 🔍 Total test images:  805
# ⚠️  Common filenames:  0
# ✅ No filename overlap detected.
